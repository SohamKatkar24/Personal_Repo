# %%
from sklearn import datasets
import numpy as np

iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target

print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
import matplotlib.pyplot as plt

plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.get_cmap('viridis',3))
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Iris Data: Petal Width vs. Petal Length')
plt.colorbar(label='Species')
plt.show()
# Out:
# C:\Users\soham\AppData\Local\Temp\ipykernel_10872\4166200717.py:3: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(X[:,0], X[:,1], c=y, cmap=plt.cm.get_cmap('viridis',3))

# %%
from sklearn.model_selection import train_test_split

#Split the data as 70% training and 30% as test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print("Training set (X, y):", X_train.shape, y_train.shape)
print("Testing set (X, y):", X_test.shape, y_test.shape)
# Out:
# Training set (X, y): (105, 2) (105,)
# Testing set (X, y): (45, 2) (45,)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


# Using Logistic Regression
logistic_reg = LogisticRegression()
logistic_reg.fit(X_train_scaled, y_train)


# Predictions on the testing data
y_pred = logistic_reg.predict(X_test_scaled)
print(y_pred)

# Plotting testing data with predictions
plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, cmap=plt.cm.get_cmap('viridis', 3))
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.title('Testing Data with Predicted Labels (Decision Tree)')
plt.colorbar(label='Predicted Species')
plt.show()
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy of Logistic Regression:", accuracy)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0 0 0 1 0 0 2 1
#  0 0 0 2 1 1 0 0]
# C:\Users\soham\AppData\Local\Temp\ipykernel_10872\2396773716.py:20: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   plt.scatter(X_test[:, 0], X_test[:, 1], c=y_pred, cmap=plt.cm.get_cmap('viridis', 3))
# Accuracy of Logistic Regression: 1.0
